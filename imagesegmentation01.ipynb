# %%
# !pip install ultralytics
from ultralytics import YOLO
# !pip install opencv-python-headless
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.2 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
import cv2
from matplotlib import pyplot as plt

# %%
# The zip file appears to be corrupted. Please re-download the file.
# !unzip "/content/Fire and Smoke Segmentation.v2i.yolov11.zip" -d "/content/"
# Out:
# Archive:  /content/Fire and Smoke Segmentation.v2i.yolov11.zip
#   inflating: /content/README.dataset.txt
#   inflating: /content/README.roboflow.txt
#   inflating: /content/data.yaml
#    creating: /content/test/
#    creating: /content/test/images/
#  extracting: /content/test/images/flare_0014_jpg.rf.0f16730fae9aa492a1897870d198442a.jpg
#  extracting: /content/test/images/flare_0028_jpg.rf.c4606d952d9e49a1fd41ff22a9997719.jpg
#  extracting: /content/test/images/flare_0029_jpg.rf.cdec1d706398c4d2f0a0660d0a8eb8bf.jpg
#  extracting: /content/test/images/flare_0057_jpg.rf.3da5706a6b81cd6ea3f002b54f22d1ff.jpg
#  extracting: /content/test/images/flare_0058_jpg.rf.1e2536affa9a722ab63e9bd311180867.jpg
#  extracting: /content/test/images/flare_0059_jpg.rf.069a956927a8491646d1fff62691a8e1.jpg
#  extracting: /content/test/images/flare_0060_jpg.rf.99ca984c597259988cb1f7c0614e36f4.jpg
#  extracting: /content/test/images/flare_0074_jpg.rf.8ea57c7218a20f38fda1be5c99a9e99e.jpg
# ...

# %%
# This path is no longer needed as data.yaml has been updated with Colab paths.
# "C:\Users\Ankit Agrawal\Downloads\crack.v1i.folder.zip\test"

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo12n.pt")  # build a new model from scratch

#model = YOLO("yolov8n-seg.pt")  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data="/content/data.yaml", epochs=200, workers=1, batch=8,imgsz=640)  # train the model
# Out:
# ...
# Ultralytics 8.3.190 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# Train segmentation model
# !yolo task=segment mode=train model=yolov8n-seg.pt data=fire_smoke.yaml epochs=100 imgsz=640
# Out:
# /bin/bash: line 1: yolo: command not found
